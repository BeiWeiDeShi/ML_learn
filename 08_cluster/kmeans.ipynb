# %% [markdown]
# # K-Means

# %%
##keep
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # 生成数据集

# %%
##keep
from sklearn.datasets import make_blobs
X, y = make_blobs(n_samples = 500, centers = 3, random_state = 42)
print(X.shape)

# %% [markdown]
# ## 画出生成数据的散点图

# %%
##keep
plt.figure(figsize = (7, 7))
rgb = np.array(['r', 'g', 'b'])
plt.scatter(X[:, 0], X[:, 1], color = rgb[y])
plt.title('Blobs')
plt.show()

# %% [markdown]
# ## 假定有3个中心点，用KMeans模型来适配数据集

# %% [markdown]
# ## 查看模型适配后的中心点

# %% [markdown]
# ## 在图上标识这三个中心点

# %%
##keep
plt.figure(figsize = (7, 7))
rgb = np.array(['r', 'g', 'b'])
plt.scatter(X[:, 0], X[:, 1], color = rgb[y])
plt.scatter(kmean.cluster_centers_[:, 0], kmean.cluster_centers_[:, 1], 
            marker = '*', s = 250, color = 'black', label = 'centers')
plt.title('Blobs')
plt.legend(loc = 'best')
plt.show()

# %% [markdown]
# ## 列出X中前5个点与三个中心点的距离

# %% [markdown]
# ## 求出轮廓系数
# 轮廓系数（Silhouette Coefficient），是聚类效果好坏的一种评价方式。

# %% [markdown]
# ## 画出轮廓系数的直方图

# %% [markdown]
# ## 计算轮廓系数得分

# %% [markdown]
# ## 寻找最佳的中心点个数
# 1. 生成有10个中心点的模拟数据集。
# 2. 将中心点个数依次取为2到60，求出相应轮廓系数得分。
# 3. 画出轮廓系数得分的曲线图，判断最佳中心点个数。
