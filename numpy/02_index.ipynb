# %% [markdown]
# # 向量索引

# %%
##keep
import numpy as np

# %% [markdown]
# ## 索引基本用法
# 构建数组，并通过图示索引来访问相应的元素。
# ![numpy_index.png](attachment:numpy_index.png)

# %% [markdown]
# ## 通过索引修改数据
# ![numpy_modify.png](attachment:numpy_modify.png)

# %% [markdown]
# ## 数据的复制
# 只有下面最后一种方法才是复制数组，如果用其他方法都可能破坏原始数据：
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 布尔运算的结果

# %%
##keep
a = np.array([1,2,3,4,5,6,7,6,5,4,3,2,1])

# %% [markdown]
# ![numpy_a_gt_5.png](attachment:numpy_a_gt_5.png)

# %% [markdown]
# ## 布尔索引
# ![np_bool_index.png](attachment:np_bool_index.png)

# %% [markdown]
# ## 基于布尔索引的赋值
# ![np_bool_assignment.png](attachment:np_bool_assignment.png)

# %%
##keep
a = np.array([1,2,3,4,5,6,7,6,5,4,3,2,1])

# %%
##keep
a = np.array([1,2,3,4,5,6,7,6,5,4,3,2,1])

# %% [markdown]
# ## np.where()

# %%
##keep
a = np.array([1,2,3,4,5,6,7,6,5,4,3,2,1])

# %% [markdown]
# ![np_where.png](attachment:np_where.png)

# %% [markdown]
# ![np_where2.png](attachment:np_where2.png)

# %% [markdown]
# ## np.clip()
# ![np_clip.png](attachment:np_clip.png)
