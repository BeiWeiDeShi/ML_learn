# %% [markdown]
# # NumPy简介
# ## 导入NumPy包

# %% [markdown]
# ## Python列表和NumPy数组
# 构造下图所示的Python列表和NumPy数组。
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 一维数组的属性
# 构造下图所示的数组，并打印出以下属性
# - dtype
# - shape
# - ndim
# - size
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 创建特定数组
# ![image.png](attachment:image.png)

# %% [markdown]
# 通常需要创建一个空数组，该空数组通过形状和元素类型与现有数组匹配
# ![image.png](attachment:image.png)

# %% [markdown]
# 类似的函数还有非常多
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 初始化单调数组
# ![image.png](attachment:image.png)
# 如果需要浮点数组，例如[0.，1.，2.]，则可以更改arange输出的类型：arange（3）.astype（float），但是有一种更好的方法。 arange函数对类型敏感：如果将int作为参数输入，它将生成int，并且如果输入浮点数（例如arange（3.）），则将生成浮点数。

# %% [markdown]
# ## 生成随机数
# ![image.png](attachment:image.png)
