# %% [markdown]
# # NumPy索引

# %% [markdown]
# ## 导入NumPy

# %%
##keep
import numpy as np

# %% [markdown]
# ## 创建数组
# 数组如下图所示：
# ![arr](images/arr.png)

# %%
##keep
a = np.array([1, 2, 3, 4, 5, 6, 7, 6, 5, 4, 3, 2, 1])

# %% [markdown]
# ## 切片索引

# %% [markdown]
# 选出数组前半部分的偶数位的元素：

# %% [markdown]
# 选出所有偶数下标的元素：

# %% [markdown]
# ## 布尔索引

# %% [markdown]
# 下面的布尔表达式的结果是什么？

# %%
##keep
a > 5

# %% [markdown]
# 找出数组a中所有大于5的元素。

# %% [markdown]
# 写出等价的布尔值做索引的表达式：

# %% [markdown]
# ## 更复杂的布尔索引

# %% [markdown]
# 取出a的值在3和5之间的所有元素：

# %% [markdown]
# 上面表达式中索引值的结果是什么？

# %% [markdown]
# ## 整数数组索引

# %% [markdown]
# 用整数数组索引取出
# ```
# [2, 3, 4]
# ```

# %% [markdown]
# 使用np.arange表达式作为索引，取出
# ```
# [5, 6, 7, 6, 5]
# ```

# %% [markdown]
# 用整数数组索引取出
# ```
# [2, 2, 3, 2]
# ```

# %% [markdown]
# ## 索引赋值

# %% [markdown]
# 将数组a中所有3和5之间（包括3和5）的值设置为0。
