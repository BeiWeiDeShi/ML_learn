# %% [markdown]
# # 线性SVM分类

# %%
##keep
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 加载iris数据集

# %%
##keep
from sklearn import datasets
iris = datasets.load_iris()

# %% [markdown]
# 只取petal length, petal width。类别只取值为0和1的两种。

# %% [markdown]
# ## 画出两类iris的散点图
# 以petal length为横坐标，petal width为纵坐标：
# 1. 画出Setosa(y值为0)的坐标
# 2. 画出Versicolor(y值为1)的坐标

# %%
##keep
plt.plot(X[:, 0][y == 0], X[:, 1][y == 0], 'yo', label = 'Iris setosa')
plt.plot(X[:, 0][y == 1], X[:, 1][y == 1], 'bs', label = 'Iris versicolor')
#画三条分割线
plt.plot([3.1, 2], [0, 2], '-k')
plt.plot([3.8, 0], [0, 1.7], '-k')
plt.plot([0, 6], [1.1, 0.7], '-k')
plt.axis([0, 5.5, 0, 2])

# %% [markdown]
# ## 构建线性SVM模型，并适配数据
# 正则参数C设置为1e9。

# %% [markdown]
# ## 自定义绘制SVC边界的函数

# %%
##keep
def plot_svc_decision_boundary(svm_clf, xmin, xmax):
    w = svm_clf.coef_[0]
    b = svm_clf.intercept_[0]

    # At the decision boundary, w0*x0 + w1*x1 + b = 0
    # => x1 = -w0/w1 * x0 - b/w1
    x0 = np.linspace(xmin, xmax, 200)
    decision_boundary = -w[0]/w[1] * x0 - b/w[1]

    margin = 1/w[1]
    gutter_up = decision_boundary + margin
    gutter_down = decision_boundary - margin

    svs = svm_clf.support_vectors_
    plt.scatter(svs[:, 0], svs[:, 1], s=180, facecolors='#FFAAAA')
    plt.plot(x0, decision_boundary, "k-", linewidth=2)
    plt.plot(x0, gutter_up, "k--", linewidth=2)
    plt.plot(x0, gutter_down, "k--", linewidth=2)

# %% [markdown]
# ## 绘制SVC边界

# %%
##keep
plt.plot(X[:, 0][y == 0], X[:, 1][y == 0], 'yo', label = 'Iris setosa')
plt.plot(X[:, 0][y == 1], X[:, 1][y == 1], 'bs', label = 'Iris versicolor')
plot_svc_decision_boundary(svc, 0, 5.5)
plt.axis([0, 5.5, 0, 2])

# %% [markdown]
# ## 特征缩放

# %%
##keep
Xs = np.array([[1, 50], [5, 20], [3, 80], [5, 60]]).astype(np.float64)
ys = np.array([0, 0, 1, 1])

# %% [markdown]
# ### 使用线性SVC，并画图

# %%
##keep
svc0 = SVC(kernel = 'linear', C = 100)
svc0.fit(Xs, ys)

# %%
##keep
plt.plot(Xs[:, 0][ys == 1], Xs[:, 1][ys == 1], 'bo')
plt.plot(Xs[:, 0][ys == 0], Xs[:, 1][ys == 0], 'ms')
plot_svc_decision_boundary(svc0, 0, 6)
plt.axis([0, 6, 0, 90])

# %% [markdown]
# ### 使用StandardScaler
# 构建StandardScaler对象。

# %% [markdown]
# 应用StandardScaler对象，让模型去适配缩放过后的数据。

# %% [markdown]
# 画出新的边界。

# %% [markdown]
# ## 使用Pipeline
