# %% [markdown]
# # 概要与映射

# %% [markdown]
# ## 导入数据

# %% [markdown]
# ## 查看所有的列名

# %% [markdown]
# ## 查看数据的概要

# %% [markdown]
# ## 列出各个不同“评估定级情况”的图书馆数量

# %% [markdown]
# ## “总藏量”减去平均值

# %% [markdown]
# ## 找出单位名称中有“金华”，“宁波”字样的图书馆数量
# 输出的数据会是下面的样子：
# ```
# 金华     8
# 宁波    19
# ```
