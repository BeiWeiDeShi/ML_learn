# %% [markdown]
# # 概要与映射

# %%
##keep
import pandas as pd

# %% [markdown]
# ## 导入数据

# %% [markdown]
# ## 查看所有的列名

# %% [markdown]
# ## 查看数据的概要

# %% [markdown]
# ## 列出各个不同“评估定级情况”的图书馆数量

# %% [markdown]
# ## “总藏量”减去平均值

# %% [markdown]
# ## 找出单位名称中有“金华”，“宁波”字样的图书馆数量
# 输出的数据会是下面的样子：
# ```
# 金华     8
# 宁波    19
# ```

# %% [markdown]
# ## 自定义等级
# 根据以下的规则，给图书馆分级：
# - A级：总藏量和电子图书相加之和大于等于10000000，建筑面积大于等于10000。
# - B级：总藏量和电子图书相加之和小于10000000，大于等于5000000，建筑面积小于10000，大于等于5000。
# - C级：其余图书馆
#
# 根据自定义等级，列出各个等级图书馆的数量。
