# %% [markdown]
# # DataFrame
# 1. DataFrame可看作是一张表，每列的数据类型可以不同。
# 2. DataFrame即有行索引，也有列索引。
# 3. DataFrame可看作是由Series字典(列)，所有Series共享相同的index。

# %%
##keep
import pandas as pd
import numpy as np

# %% [markdown]
# ## 通过等长数组来构造DataFrame

# %%
##keep
data = {'state': ['Ohio', 'Ohio', 'Ohio', 'Nevada', 'Nevada', 'Nevada'],
    'year': [2000, 2001, 2002, 2001, 2002, 2003],
    'pop': [1.5, 1.7, 3.6, 2.4, 2.9, 3.2]}
frame = pd.DataFrame(data)
frame

# %% [markdown]
# ## 指定列的次序

# %%
##keep
pd.DataFrame(data, columns=['year', 'state', 'pop'])

# %% [markdown]
# ## 添加没有数据的列

# %%
##keep
frame2 = pd.DataFrame(data, columns=['year', 'state', 'pop', 'debt'],
    index=['one', 'two', 'three', 'four',
    'five', 'six'])
frame2

# %% [markdown]
# ## 获取指定的列

# %% [markdown]
# ## 获取指定行

# %% [markdown]
# ## 对列赋值

# %% [markdown]
# ## 将Series赋值给列，会在索引处对齐

# %%
##keep
val = pd.Series([-1.2, -1.5, -1.7], index = ['two', 'four', 'five'])
frame2['debt'] = val
frame2

# %% [markdown]
# ## 删除列

# %% [markdown]
# ## 用字典中的字典来创建DataFrame

# %%
##keep
pop = {'Nevada': {2001: 2.4, 2002: 2.9},
    'Ohio': {2000: 1.5, 2001: 1.7, 2002: 3.6}}
frame3 = pd.DataFrame(pop)
frame3

# %% [markdown]
# ## DataFrame的转置

# %% [markdown]
# ## 指定行索引的次序

# %% [markdown]
# ## 用Series字典来构造DataFrame

# %% [markdown]
# ## index和columns的name属性

# %% [markdown]
# ## 获得DataFrame内部的ndarray
