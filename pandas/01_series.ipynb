# %% [markdown]
# # Series
# Series由一维数组及索引组成。

# %% [markdown]
# ## 最简单的Series

# %%
##keep
obj = pd.Series([4, 7, -5, 3])

# %% [markdown]
# ## 查看值和索引

# %% [markdown]
# ## 以字符串作为索引的Series

# %%
##keep
obj2 = pd.Series([4, 7, -5, 3], index = ['d', 'b', 'a', 'c'])

# %% [markdown]
# ## 用索引来访问对应的值

# %% [markdown]
# ## 可以使用类似于NumPy的操作

# %%
##keep
obj2[obj2 > 0]

# %%
##keep
obj2 * 2

# %% [markdown]
# ## 从Python字典创建Series

# %%
##keep
sdata = {'ShangHai': 2426, 'BeiJing': 2152, 'GuangZhou': 1324, 'ShuZhou': 1060}
obj3 = pd.Series(sdata)
obj3

# %% [markdown]
# ## 使用自定义索引

# %%
##keep
states = ['BeiJing', 'GuangZhou', 'ChengDu', 'ShangHai']
obj4 = pd.Series(sdata, index = states)
obj4

# %% [markdown]
# ## 判断NA值

# %% [markdown]
# ## 索引自动对齐

# %% [markdown]
# ## name属性
# Series对象及索引对象都有name属性。

# %% [markdown]
# ## 修改索引
