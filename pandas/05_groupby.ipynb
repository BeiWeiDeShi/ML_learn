# %% [markdown]
# # 分组与排序
# ## 导入数据

# %%
##keep
import pandas as pd
reviews = pd.read_csv('datasets/winemag-data-130k-v2.csv', index_col=0)
reviews.head()

# %% [markdown]
# ## 找出常见的品酒师
# 创建满足下面的条件的Series:
# - 索引为taster_twitter_handle
# - 值为该品酒师评论的数量

# %% [markdown]
# ## 找出每个评分点上最便宜的酒
# 创建满足下面的条件的Series:
# - 索引为points
# - 值为对应points上price的最小值

# %% [markdown]
# ## 每个酿酒厂(winery)中挑出一种酒
# 创建满足下面的条件的Series:
# - 索引为winery
# - 值为第一种被品评的酒的title

# %% [markdown]
# ## 每个省份得分最高的酒
# 创建满足下面的条件的DataFrame：
# - 索引为country, province
# - 只包含该country, province下的得分最高的行

# %% [markdown]
# ## 找出每个品类的最低价与最高价
# 创建满足下面的条件的DataFrame：
# - 索引为variety
# - min列为该品类下的最低价
# - max列为该品类下的最高价

# %% [markdown]
# ## 找出最常见的国家与品类的组合
# 创建满足下面的条件的Series:
# - 索引为country, variety
# - 值为对应的记录的数量
# - 按值的大小，从高到低排列
