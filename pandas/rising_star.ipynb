# %% [markdown]
# # 数据的选择

# %%
##keep
import pandas as pd

# %% [markdown]
# ## 导入数据

# %% [markdown]
# ## 选出“工作单位”所在的列

# %% [markdown]
# ## 选出“工作单位”中的第0个值

# %% [markdown]
# ## 选出数据的第0行

# %% [markdown]
# ## 选出前10个“工作单位”

# %% [markdown]
# ## 选出指定区域中的数据
# - 行下标为0, 1, 10, 100
# - 列只包括“姓名”，“工作单位”， “获选时间”

# %% [markdown]
# ## 选出所有”镇海中学“的行

# %% [markdown]
# ## 选出2010年到2020年间，以下几个学校的获选记录
# - 浙江金华第一中学
# - 嘉兴市第一中学
# - 宁波外国语学校
# 结果集中只保留“年度”，“姓名”，“工作单位”。
