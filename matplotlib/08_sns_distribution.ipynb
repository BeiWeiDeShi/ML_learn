# %% [markdown]
# # SNS 分布图

# %%
##keep
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 加载数据
# benign tumors（良性肿瘤）
#
# malignant tumors（恶性肿瘤）

# %%
##keep
cancer_b = pd.read_csv('./datasets/cancer_b.csv', index_col=0)
cancer_m = pd.read_csv('./datasets/cancer_m.csv', index_col=0)

# %% [markdown]
# ## histplot
# 画出两种肿瘤平均面积的分布图。平均面积 - Area(mean)

# %% [markdown]
# ## 核密度估计(KDE-Kernel Density Estimation)
# KDE在概率论中用来估计未知的密度函数。
