# %% [markdown]
# # 不一致数据的处理

# %%
##keep
# pip3 install python-Levenshtein thefuzz
import pandas as pd
from thefuzz import process
from thefuzz import fuzz

# %% [markdown]
# ## 导入数据

# %%
##keep
professors = pd.read_csv('./datasets/pakistan_intellectual_capital.csv')
professors.head()

# %% [markdown]
# ## 查看Country列的数据
# 用unique查看不同的Country。

# %% [markdown]
# ## 清除大小写与空格
# 将Country全部转换成小写，并清除字符前后的空格。

# %% [markdown]
# ## 使用模糊匹配
# 查找与"south korea"最匹配的前10个国家名称。

# %% [markdown]
# ## 将匹配程度较高的字段替换掉
# 匹配ratio大于47分的Country字段，可替换成'south korea'。

# %% [markdown]
# ## 验证修改的结果

# %% [markdown]
# ## 查找Country字段中与"usa"相似的国家名称

# %% [markdown]
# ## 替换与"usa"匹配程度高的国家名称
