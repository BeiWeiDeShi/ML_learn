# %% [markdown]
# # Series
# Series由一维数组及索引组成。

# %% [markdown]
# ## 最简单的Series

# %%
##keep
obj = pd.Series([18753.73, 21462.69, 22990.35])

# %% [markdown]
# ## 查看值和索引

# %% [markdown]
# ## 创建时指定索引

# %%
##keep
obj2 = pd.Series([18753.73, 21462.69, 22990.35], index=['2007', '2008', '2009'])

# %% [markdown]
# ## 查看obj2值和索引

# %% [markdown]
# ## 访问索引为2007的值

# %% [markdown]
# ## 选出2007和2008年的数据

# %% [markdown]
# ## 选出大于20000的数据

# %% [markdown]
# ## 从Python字典创建Series

# %%
##keep
sdata = {'ShangHai': 2426, 'BeiJing': 2152, 'GuangZhou': 1324, 'ShuZhou': 1060}
obj3 = pd.Series(sdata)
obj3

# %% [markdown]
# ## 使用自定义索引

# %%
##keep
cities = ['BeiJing', 'GuangZhou', 'ChengDu', 'ShangHai']
obj4 = pd.Series(sdata, index = cities)
obj4

# %% [markdown]
# ## 判断NA值

# %% [markdown]
# ## 索引自动对齐
