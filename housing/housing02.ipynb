# %% [markdown]
# # 数据可视化和相关性

# %% [markdown]
# ## 加载数据

# %%
##keep
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
##keep
housing = pd.read_csv('../datasets/housing/housing.csv')
housing.head()

# %% [markdown]
# ## 根据地理位置展示数据

# %% [markdown]
# ## 用点的大小展示population，用颜色展示median_house_value

# %% [markdown]
# ## 查看每对数值属性之间的散点图

# %%
##keep
num_columns = [
    'median_house_value', 'median_income', 'total_rooms', 'housing_median_age',
    'total_bedrooms', 'households', 'population'
]

# %% [markdown]
# ## 计算每对属性之间的相关系数

# %% [markdown]
# ## 查看各属性与median_house_value的相关性

# %% [markdown]
# ## 添加三个新属性

# %%
##keep
# 平均每家庭房间数量
housing['rooms_per_household'] = housing.total_rooms / housing.households
# 卧室数量与房间数量的比值
housing['bedrooms_to_rooms'] = housing.total_bedrooms / housing.total_rooms
# 每个家庭人口数
housing['population_per_household'] = housing.population / housing.households

# %% [markdown]
# ## 查看房价中位数与各个属性之间的相关系数
