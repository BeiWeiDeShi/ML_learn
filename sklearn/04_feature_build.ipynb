# %% [markdown]
# # 特征构建

# %%
##keep
import pandas as pd #导入Pandas
import numpy as np #导入NumPy
import matplotlib.pyplot as plt #导入绘图工具
df = pd.read_csv('./datasets/feature_build.csv') #导入数据
df.head()

# %% [markdown]
# ## 画出散点图

# %% [markdown]
# ## 线性回归进行建模

# %% [markdown]
# ## 用线性模型来训练

# %% [markdown]
# ## 做出预测

# %% [markdown]
# ## 画出拟合曲线

# %% [markdown]
# ## 计算均方差和R2分数

# %% [markdown]
# ## 构建一个新特征
# 在 X 的基础上做个平方，构建出一个新特征。

# %% [markdown]
# ## 用新的线程模型去训练

# %% [markdown]
# ## 做出新的预测

# %% [markdown]
# ## 画出新的拟合曲线

# %% [markdown]
# ## 计算新的均方差和R2分数
