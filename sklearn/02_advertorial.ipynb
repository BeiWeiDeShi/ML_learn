# %% [markdown]
# # 营销软文浏览量预测

# %%
##keep
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['font.sans-serif'] = ['AR PL UMing CN']
plt.rcParams['axes.unicode_minus'] = False

# %%
##keep
adv = pd.read_csv('./datasets/advertorial.csv')
adv.head()

# %% [markdown]
# ## 可视化分析
# ### 画出点赞数与浏览量之间的散点图

# %% [markdown]
# ### 画出热度指数与浏览量的箱线图

# %% [markdown]
# ## 数据清洗

# %% [markdown]
# ## 分离特征集与标签集

# %% [markdown]
# ## 拆分训练集与测试集

# %% [markdown]
# ## 构建模型

# %% [markdown]
# ## 训练模型

# %% [markdown]
# ## 预测

# %% [markdown]
# ## 显示残差
# 残差即是真实值(target)与预测值(predictions)之间的差。

# %% [markdown]
# ## 预测评分

# %% [markdown]
# ## 查看模型
