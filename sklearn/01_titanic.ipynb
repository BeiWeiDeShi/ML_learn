# %% [markdown]
# # 泰坦尼克生还者预测

# %%
##keep
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 加载数据
# 数据字段说明：
# * Survived：是否存活（0代表否，1代表是）
# * Pclass：船舱等级（1代表高级船舱，2代表中级船舱，3代表低级船舱）
# * Name：船上乘客的名字
# * Sex：船上乘客的性别
# * Age:船上乘客的年龄（可能存在 NaN）
# * SibSp：乘客在船上的兄弟姐妹和配偶的数量
# * Parch：乘客在船上的父母以及小孩的数量
# * Ticket：乘客船票的编号
# * Fare：乘客为船票支付的费用
# * Cabin：乘客所在船舱的编号（可能存在 NaN，表示不存在）
# * Embarked：乘客上船的港口（C 代表从 Cherbourg 登船，Q 代表从 Queenstown 登船，S 代表从 Southampton 登船）
#
# 以PassengerId为索引。

# %%
##keep
titanic = pd.read_csv('./datasets/titanic.csv', index_col='PassengerId')
titanic.head()

# %% [markdown]
# ## 数据清洗

# %% [markdown]
# ### 查看缺失值

# %% [markdown]
# ### Age字段用平均值来替代

# %% [markdown]
# ### 丢弃Cabin列
# Cabin列数据丢失太多，直接丢弃。

# %% [markdown]
# ### 处理Embarked的空值
# 分析Embarked的取值情况，选出占比最大的值来填充空值。

# %% [markdown]
# ## 特征选择
# Name 为乘客姓名，对分类没有作用，可以放弃。Ticket 字段为船票号码，杂乱无章且无规律，可以放弃。

# %% [markdown]
# ## 分离标签

# %% [markdown]
# ## 将字符串转换成数字

# %% [markdown]
# ## 分割训练集与测试集

# %% [markdown]
# ## 构建模型

# %% [markdown]
# ## 预测评估
