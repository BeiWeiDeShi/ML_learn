# %% [markdown]
# # MNIST数据集

# %% [markdown]
# ## 下载数据集

# %%
##keep
from sklearn.datasets import fetch_openml
mnist = fetch_openml('mnist_784', version = 1)

# %% [markdown]
# ## 查看数据集

# %% [markdown]
# ## 自定义plot_digit函数
# 28 * 28 = 784

# %% [markdown]
# ## 显示一个数字

# %% [markdown]
# ## 查看该数字的标签

# %% [markdown]
# ## 将y转换成整型数值

# %% [markdown]
# ## 不容易辨认的数字图形

# %% [markdown]
# ## 用模型认出数字5
